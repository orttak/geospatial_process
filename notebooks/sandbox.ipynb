# %%
import os
import json
import rasterio
import requests

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = rasterio.open('https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/37/S/DA/2020/7/S2B_37SDA_20200706_0_L2A/B02.tif')

# %%
img
# Out:
# <open DatasetReader name='https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/37/S/DA/2020/7/S2B_37SDA_20200706_0_L2A/B02.tif' mode='r'>

# %%
import xarray as xr
url='https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/37/S/DA/2020/7/S2B_37SDA_20200706_0_L2A/B08.tif'
red = xr.open_rasterio(url, chunks={'band': 1, 'x': 1024, 'y': 1024})

# %%
red
# Out:
# <xarray.DataArray (band: 1, y: 10980, x: 10980)>
# dask.array<open_rasterio-c954ff7a9d336097644e52e2417b9c93<this-array>, shape=(1, 10980, 10980), dtype=uint16, chunksize=(1, 1024, 1024), chunktype=numpy.ndarray>
# Coordinates:
#   * band     (band) int64 1
#   * y        (y) float64 4.1e+06 4.1e+06 4.1e+06 ... 3.99e+06 3.99e+06 3.99e+06
#   * x        (x) float64 4e+05 4e+05 4e+05 ... 5.097e+05 5.097e+05 5.098e+05
# Attributes:
#     transform:           (10.0, 0.0, 399960.0, 0.0, -10.0, 4100040.0)
#     crs:                 +init=epsg:32637
#     res:                 (10.0, 10.0)
#     is_tiled:            1
#     nodatavals:          (0.0,)
#     scales:              (1.0,)
#     offsets:             (0.0,)
#     AREA_OR_POINT:       Area
#     OVR_RESAMPLING_ALG:  AVERAGE
